# %%
# !wget -c "https://dax-cdn.cdn.appdomain.cloud/dax-publaynet/1.0.0/train-1.tar.gz" --no-check-certificate
##https://dax-cdn.cdn.appdomain.cloud/dax-publaynet/1.0.0/labels.tar.gz
# Out:
# --2022-08-22 19:07:02--  https://dax-cdn.cdn.appdomain.cloud/dax-publaynet/1.0.0/train-1.tar.gz
# Resolving dax-cdn.cdn.appdomain.cloud (dax-cdn.cdn.appdomain.cloud)... 23.66.171.192, 2600:1407:1d:482::d2d, 2600:1407:1d:48b::d2d
# Connecting to dax-cdn.cdn.appdomain.cloud (dax-cdn.cdn.appdomain.cloud)|23.66.171.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13629604267 (13G) [application/x-gzip]
# Saving to: ‘train-1.tar.gz’
#
# train-1.tar.gz      100%[===================>]  12.69G  6.86MB/s    in 36m 56s
#
# 2022-08-22 19:43:59 (5.87 MB/s) - ‘train-1.tar.gz’ saved [13629604267/13629604267]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
for image in os.listdir("/content/drive/My Drive/images/publaynet/train/"):

# %%
# !tar -xvf  "/content/drive/MyDrive/train-1.tar.gz" -C "/content/drive/My Drive/images/"
# Out:
# tar: /content/drive/MyDrive/train-1.tar.gz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
import os

i=0
for _ in os.listdir("/content/drive/My Drive/images/publaynet/train/"):
  i+=1

print(f"there are {i} page")
# Out:
# there are 28608 page

# %%
# !wget -c "https://dax-cdn.cdn.appdomain.cloud/dax-publaynet/1.0.0/train-1.tar.gz" --no-check-certificate
# Out:
# --2022-08-20 20:17:28--  https://dax-cdn.cdn.appdomain.cloud/dax-publaynet/1.0.0/labels.tar.gz
# Resolving dax-cdn.cdn.appdomain.cloud (dax-cdn.cdn.appdomain.cloud)... 104.96.216.159, 2600:141b:e800:3083::d2d, 2600:141b:e800:3086::d2d
# Connecting to dax-cdn.cdn.appdomain.cloud (dax-cdn.cdn.appdomain.cloud)|104.96.216.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 329162762 (314M) [application/x-gzip]
# Saving to: ‘labels.tar.gz’
#
# labels.tar.gz       100%[===================>] 313.91M  68.0MB/s    in 5.0s
#
# 2022-08-20 20:17:33 (62.5 MB/s) - ‘labels.tar.gz’ saved [329162762/329162762]
